# %%
import pandas as pd

# %%
becl = pd.read_csv("/Users/aeshaanwahlang/Documents/QuantitativeSemanticsData/BECL_2.1_master.csv", sep=";", encoding="ISO-8859-1")
print(becl)
# Out:
#       id_and_sense         lemma  wordnet_senseindex_number  \
# 0          25085,2            aa                          2
# 1          25085,3            aa                          3
# 2          40178,1  abbreviation                          1
# 3          20030,1     aberrancy                          1
# 4          24831,1    aberration                          1
# 5          24831,2    aberration                          2
# 6          24831,3    aberration                          3
# 7          42805,1   abnormality                          1
# 8          14926,1  abolitionist                          1
# 9          30579,2      abortion                          2
# 10         21433,1    about-face                          1
# 11         21433,2    about-face                          2
# 12         18882,1       abscess                          1
# 13         30010,4       absence                          4
# 14          1335,1      absentee                          1
# ...

# %%
t = "id_and_sense;lemma;wordnet_senseindex_number;wordnet_description;wordnet_total_senses;sense_synset;similar.LCH..2.5;occurrences_in_oanc_total;occurrences_singular_in_oanc;occurrences_plural_in_oanc;Test_I_1;Test_I_2;Test_II_1;Test_II_2;Test_III_1;Test_III_2;comment;idiomatic;nominalization;result_state;process;act_event;proper_name_final;Phase_No;annotators;class;major_class;adjudication;complete;variation_in_writing;multiple;unit/letter"
s = t.split(";")
print(s[31])
# Out:
# unit/letter

# %%
t1 = "25085,2;aa;2;an international organization that provides a support group for persons trying to overcome alcoholism;3;alcoholics_anonymous.n.01;organization.n.01,  nongovernmental_organization.n.01,  alcoholics_anonymous.n.01,  greenpeace.n.01,  markaz-ud-dawa-wal-irshad.n.01,  red_cross.n.01,  salvation_army.n.01,  umma_tameer-e-nau.n.01,  national_trust.n.01,  denomination.n.01,  congress_of_racial_equality.n.01,  committee.n.02,  mission.n.01;306;305;1;no;not applicable;not applicable;not applicable;no;yes;PN.;;;;;;proper_name, organization;12;FW+MD;523;neither_mass_count;NA;NA;NA;Yes;NA"
s1 = t1.split(";")
print(len(s1))
# Out:
# 32
